# %%
import geopandas

path_to_data = geopandas.datasets.get_path('nybb')
gdf = geopandas.read_file(path_to_data)
gdf
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf = gdf.set_index('BoroName')

# %%
gdf['area'] = gdf.area
gdf['area']
# Out:
# BoroName
# Staten Island    1.623822e+09
# Queens           3.045214e+09
# Brooklyn         1.937478e+09
# Manhattan        6.364712e+08
# Bronx            1.186926e+09
# Name: area, dtype: float64

# %%
gdf['boundary'] = gdf.boundary
gdf['boundary']
# Out:
# BoroName
# Staten Island    MULTILINESTRING ((970217.022 145643.332, 97022...
# Queens           MULTILINESTRING ((1029606.077 156073.814, 1029...
# Brooklyn         MULTILINESTRING ((1021176.479 151374.797, 1021...
# Manhattan        MULTILINESTRING ((981219.056 188655.316, 98094...
# Bronx            MULTILINESTRING ((1012821.806 229228.265, 1012...
# Name: boundary, dtype: geometry

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5 entries, Staten Island to Bronx
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BoroCode    5 non-null      int64
#  1   Shape_Leng  5 non-null      float64
#  2   Shape_Area  5 non-null      float64
#  3   geometry    5 non-null      geometry
#  4   area        5 non-null      float64
#  5   boundary    5 non-null      geometry
# dtypes: float64(3), geometry(2), int64(1)
# memory usage: 452.0+ bytes

# %% [markdown]
# The `geometry` and `boundary` columns are of type `geometry`

# %%
# plot the active geometry
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.plot('area', legend=True)  # color code by another column
# Out:
# <AxesSubplot:>

# %%
# gdf.explore('area')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
gdf['geometry'].plot(ax=ax)
gdf['geometry'].centroid.plot(ax=ax, color='black')
# Out:
# <AxesSubplot:>

# %%
# see the active geometry column
gdf.geometry
# Out:
# BoroName
# Staten Island    MULTIPOLYGON (((970217.022 145643.332, 970227....
# Queens           MULTIPOLYGON (((1029606.077 156073.814, 102957...
# Brooklyn         MULTIPOLYGON (((1021176.479 151374.797, 102100...
# Manhattan        MULTIPOLYGON (((981219.056 188655.316, 980940....
# Bronx            MULTIPOLYGON (((1012821.806 229228.265, 101278...
# Name: geometry, dtype: geometry
